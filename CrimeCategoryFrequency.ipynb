# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime=pd.read_csv('samplecrime.csv')
crime
# Out:
#       IncidntNum       Category                        Descript  DayOfWeek  \
# 0      140009459          ARSON                           ARSON   Saturday
# 1      140042001          FRAUD    CREDIT CARD, THEFT BY USE OF  Wednesday
# 2      140071185  VEHICLE THEFT               STOLEN AUTOMOBILE   Thursday
# 3      140094892        ASSAULT                         BATTERY   Saturday
# 4      140096371        ROBBERY           ROBBERY, BODILY FORCE     Sunday
# ...          ...            ...                             ...        ...
# 1001   146005625  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO   Thursday
# 1002   146005647  LARCENY/THEFT         PETTY THEFT OF PROPERTY   Thursday
# 1003   146005669  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO   Thursday
# 1004   146005744  LARCENY/THEFT         PETTY THEFT OF PROPERTY     Friday
# 1005   146005750  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO     Friday
#
#            Date   Time PdDistrict      Resolution                  Address  \
# 0      1/4/2014   3:52   NORTHERN  ARREST, BOOKED  SACRAMENTO ST / POLK ST
# 1      1/5/2014  12:30    CENTRAL            NONE     SANSOME ST / BUSH ST
# 2      1/6/2014  18:00    TARAVAL            NONE     WILSON ST / RHINE ST
# 3      1/7/2014  16:33   SOUTHERN            NONE       MARKET ST / 3RD ST
# 4      1/8/2014   6:50   SOUTHERN            NONE     MISSION ST / 11TH ST
# ...         ...    ...        ...             ...                      ...
# 1001  10/1/2016  20:00   NORTHERN            NONE     POST ST / WEBSTER ST
# 1002  10/2/2016  19:20   NORTHERN            NONE     VANNESS AV / TURK ST
# 1003  10/3/2016  19:25   NORTHERN            NONE  PIERCE ST / CHESTNUT ST
# 1004  10/4/2016  19:00    CENTRAL            NONE     LARKIN ST / GEARY ST
# 1005  10/5/2016  19:00   NORTHERN            NONE    FRANKLIN ST / POST ST
#
#                X          Y                               Location
# 0    -122.420875  37.791494  (37.7914943051906, -122.420874632415)
# 1    -122.400749  37.791178  (37.7911776792224, -122.400748631911)
# 2    -122.461139  37.709085  (37.7090849156407, -122.461139183524)
# 3    -122.403434  37.787643    (37.78764305018, -122.403434086745)
# 4    -122.417105  37.774324  (37.7743242867908, -122.417104895556)
# ...          ...        ...                                    ...
# 1001 -122.431370  37.785373  (37.7853730435472, -122.431369772433)
# 1002 -122.420642  37.781961  (37.7819608221838, -122.420641893733)
# 1003 -122.439505  37.800402  (37.8004024933613, -122.439504944797)
# 1004 -122.418091  37.786101  (37.7861007451645, -122.418090766692)
# 1005 -122.423218  37.786402  (37.7864017954155, -122.423217673913)
#
# [1006 rows x 12 columns]

# %%
type(crime)
# Out:
# pandas.core.frame.DataFrame

# %%
crime.dtypes #to find datatypes of the crime dataset variables; if python doesn't recognise datatype it gives object as output
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# DayOfWeek      object
# Date           object
# Time           object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# dtype: object

# %%
crime.head(10) #top 5 rows to be displayed: paramter if passed will give that many rows
# Out:
#    IncidntNum        Category                                        Descript  \
# 0   140009459           ARSON                                           ARSON
# 1   140042001           FRAUD                    CREDIT CARD, THEFT BY USE OF
# 2   140071185   VEHICLE THEFT                               STOLEN AUTOMOBILE
# 3   140094892         ASSAULT                                         BATTERY
# 4   140096371         ROBBERY                           ROBBERY, BODILY FORCE
# 5   140127540         ASSAULT                            THREATS AGAINST LIFE
# 6   150017276    NON-CRIMINAL                    AIDED CASE, MENTAL DISTURBED
# 7   150007374  OTHER OFFENSES                                      CONSPIRACY
# 8   150017787  OTHER OFFENSES  FALSE PERSONATION TO RECEIVE MONEY OR PROPERTY
# 9   140152274         ASSAULT                 AGGRAVATED ASSAULT WITH A KNIFE
#
#    DayOfWeek       Date   Time PdDistrict      Resolution  \
# 0   Saturday   1/4/2014   3:52   NORTHERN  ARREST, BOOKED
# 1  Wednesday   1/5/2014  12:30    CENTRAL            NONE
# 2   Thursday   1/6/2014  18:00    TARAVAL            NONE
# 3   Saturday   1/7/2014  16:33   SOUTHERN            NONE
# 4     Sunday   1/8/2014   6:50   SOUTHERN            NONE
# 5  Wednesday   1/9/2014  16:54    BAYVIEW            NONE
# 6    Tuesday  1/10/2014  16:53   NORTHERN            NONE
# 7   Saturday  1/11/2014  14:06   SOUTHERN  ARREST, BOOKED
# 8    Tuesday  1/12/2014  13:00  INGLESIDE            NONE
# 9  Wednesday  1/13/2014   2:00  INGLESIDE            NONE
#
#                     Address           X          Y  \
# 0   SACRAMENTO ST / POLK ST -122.420875  37.791494
# 1      SANSOME ST / BUSH ST -122.400749  37.791178
# 2      WILSON ST / RHINE ST -122.461139  37.709085
# 3        MARKET ST / 3RD ST -122.403434  37.787643
# 4      MISSION ST / 11TH ST -122.417105  37.774324
# 5   SAN BRUNO AV / BACON ST -122.403595  37.727634
# 6     700 Block of ELLIS ST -122.418562  37.784185
# 7  JONES ST / MCALLISTER ST -122.411979  37.780904
# 8  2900 Block of ALEMANY BL -122.452619  37.711687
# 9      MISSION ST / 30TH ST -122.421971  37.742375
#
#                                 Location
# 0  (37.7914943051906, -122.420874632415)
# 1  (37.7911776792224, -122.400748631911)
# 2  (37.7090849156407, -122.461139183524)
# 3    (37.78764305018, -122.403434086745)
# 4  (37.7743242867908, -122.417104895556)
# 5  (37.7276340992506, -122.403595293514)
# 6  (37.7841847091303, -122.418562097105)
# 7  (37.7809039696758, -122.411979487494)
# 8  (37.7116873915892, -122.452619318946)
# 9  (37.7423752245255, -122.421970919029)

# %%
crime['Category']
crime1=crime[['Category','DayOfWeek','PdDistrict']]
crime1
# Out:
#            Category  DayOfWeek PdDistrict
# 0             ARSON   Saturday   NORTHERN
# 1             FRAUD  Wednesday    CENTRAL
# 2     VEHICLE THEFT   Thursday    TARAVAL
# 3           ASSAULT   Saturday   SOUTHERN
# 4           ROBBERY     Sunday   SOUTHERN
# ...             ...        ...        ...
# 1001  LARCENY/THEFT   Thursday   NORTHERN
# 1002  LARCENY/THEFT   Thursday   NORTHERN
# 1003  LARCENY/THEFT   Thursday   NORTHERN
# 1004  LARCENY/THEFT     Friday    CENTRAL
# 1005  LARCENY/THEFT     Friday   NORTHERN
#
# [1006 rows x 3 columns]

# %%
count_category=crime['Category'].value_counts() # value_counts() gives the count of offences of each category
count_category
# Out:
# OTHER OFFENSES                 192
# LARCENY/THEFT                  190
# NON-CRIMINAL                   154
# ASSAULT                        124
# WARRANTS                        58
# DRUG/NARCOTIC                   48
# VEHICLE THEFT                   46
# ROBBERY                         40
# VANDALISM                       27
# SUSPICIOUS OCC                  23
# MISSING PERSON                  20
# FRAUD                           17
# DRUNKENNESS                     10
# ARSON                            8
# WEAPON LAWS                      7
# BURGLARY                         6
# SECONDARY CODES                  6
# RUNAWAY                          5
# PROSTITUTION                     4
# FORGERY/COUNTERFEITING           4
# KIDNAPPING                       4
# TRESPASS                         4
# DISORDERLY CONDUCT               3
# LIQUOR LAWS                      2
# DRIVING UNDER THE INFLUENCE      2
# RECOVERED VEHICLE                1
# FAMILY OFFENSES                  1
# Name: Category, dtype: int64

# %%
type(count_category)
# Out:
# pandas.core.series.Series

# %%
# converting Series into a 2D data structure
df=pd.DataFrame(count_category)
df
# Out:
#                              Category
# OTHER OFFENSES                    192
# LARCENY/THEFT                     190
# NON-CRIMINAL                      154
# ASSAULT                           124
# WARRANTS                           58
# DRUG/NARCOTIC                      48
# VEHICLE THEFT                      46
# ROBBERY                            40
# VANDALISM                          27
# SUSPICIOUS OCC                     23
# MISSING PERSON                     20
# FRAUD                              17
# DRUNKENNESS                        10
# ARSON                               8
# WEAPON LAWS                         7
# BURGLARY                            6
# SECONDARY CODES                     6
# RUNAWAY                             5
# PROSTITUTION                        4
# FORGERY/COUNTERFEITING              4
# KIDNAPPING                          4
# TRESPASS                            4
# DISORDERLY CONDUCT                  3
# LIQUOR LAWS                         2
# DRIVING UNDER THE INFLUENCE         2
# RECOVERED VEHICLE                   1
# FAMILY OFFENSES                     1

# %%
# the leftmost column should be a proper index, so we need to do the following:
DF1=df.reset_index()
DF1
# Out:
#                           index  Category
# 0                OTHER OFFENSES       192
# 1                 LARCENY/THEFT       190
# 2                  NON-CRIMINAL       154
# 3                       ASSAULT       124
# 4                      WARRANTS        58
# 5                 DRUG/NARCOTIC        48
# 6                 VEHICLE THEFT        46
# 7                       ROBBERY        40
# 8                     VANDALISM        27
# 9                SUSPICIOUS OCC        23
# 10               MISSING PERSON        20
# 11                        FRAUD        17
# 12                  DRUNKENNESS        10
# 13                        ARSON         8
# 14                  WEAPON LAWS         7
# 15                     BURGLARY         6
# 16              SECONDARY CODES         6
# 17                      RUNAWAY         5
# 18                 PROSTITUTION         4
# 19       FORGERY/COUNTERFEITING         4
# 20                   KIDNAPPING         4
# 21                     TRESPASS         4
# 22           DISORDERLY CONDUCT         3
# 23                  LIQUOR LAWS         2
# 24  DRIVING UNDER THE INFLUENCE         2
# 25            RECOVERED VEHICLE         1
# 26              FAMILY OFFENSES         1

# %%
# renaming the column names of the dataframe
DF1.columns=['Category','Frequency']
DF1
Sample=DF1.head();
Sample
# Out:
#          Category  Frequency
# 0  OTHER OFFENSES        192
# 1   LARCENY/THEFT        190
# 2    NON-CRIMINAL        154
# 3         ASSAULT        124
# 4        WARRANTS         58

# %%
# create a bar chart: Data visualisation

plt.bar(Sample['Category'],Sample['Frequency'],color="Blue")
plt.xlabel("Cateory")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.title("The frequency of Category of Crime")
plt.show()
