# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime=pd.read_csv('samplecrime.csv')
crime
# Out:
#       IncidntNum       Category                        Descript  DayOfWeek  \
# 0      140009459          ARSON                           ARSON   Saturday
# 1      140042001          FRAUD    CREDIT CARD, THEFT BY USE OF  Wednesday
# 2      140071185  VEHICLE THEFT               STOLEN AUTOMOBILE   Thursday
# 3      140094892        ASSAULT                         BATTERY   Saturday
# 4      140096371        ROBBERY           ROBBERY, BODILY FORCE     Sunday
# ...          ...            ...                             ...        ...
# 1001   146005625  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO   Thursday
# 1002   146005647  LARCENY/THEFT         PETTY THEFT OF PROPERTY   Thursday
# 1003   146005669  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO   Thursday
# 1004   146005744  LARCENY/THEFT         PETTY THEFT OF PROPERTY     Friday
# 1005   146005750  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO     Friday
#
# ...

# %%
type(crime)
# Out:
# pandas.core.frame.DataFrame

# %%
crime['DayOfWeek']
crime1=crime[['Category','DayOfWeek','Date','Time']]
crime1
# Out:
#            Category  DayOfWeek       Date   Time
# 0             ARSON   Saturday   1/4/2014   3:52
# 1             FRAUD  Wednesday   1/5/2014  12:30
# 2     VEHICLE THEFT   Thursday   1/6/2014  18:00
# 3           ASSAULT   Saturday   1/7/2014  16:33
# 4           ROBBERY     Sunday   1/8/2014   6:50
# ...             ...        ...        ...    ...
# 1001  LARCENY/THEFT   Thursday  10/1/2016  20:00
# 1002  LARCENY/THEFT   Thursday  10/2/2016  19:20
# 1003  LARCENY/THEFT   Thursday  10/3/2016  19:25
# 1004  LARCENY/THEFT     Friday  10/4/2016  19:00
# 1005  LARCENY/THEFT     Friday  10/5/2016  19:00
#
# [1006 rows x 4 columns]

# %%
count_dayofweek=crime['DayOfWeek'].value_counts()
count_dayofweek
# Out:
# Wednesday    209
# Thursday     184
# Friday       162
# Sunday       126
# Saturday     111
# Monday       110
# Tuesday      104
# Name: DayOfWeek, dtype: int64

# %%
type(count_dayofweek)
# Out:
# pandas.core.series.Series

# %%
df=pd.DataFrame(count_dayofweek)
df
# Out:
#            DayOfWeek
# Wednesday        209
# Thursday         184
# Friday           162
# Sunday           126
# Saturday         111
# Monday           110
# Tuesday          104

# %%
# reset
DF1=df.reset_index()
DF1
# Out:
#        index  DayOfWeek
# 0  Wednesday        209
# 1   Thursday        184
# 2     Friday        162
# 3     Sunday        126
# 4   Saturday        111
# 5     Monday        110
# 6    Tuesday        104

# %%
# rename
DF1.columns=['DayOfWeek','Freq of crime']
DF1
Sample=DF1.head(7)
Sample
# Out:
#    DayOfWeek  Freq of crime
# 0  Wednesday            209
# 1   Thursday            184
# 2     Friday            162
# 3     Sunday            126
# 4   Saturday            111
# 5     Monday            110
# 6    Tuesday            104

# %%
# create bar chart
plt.bar(Sample['DayOfWeek'],Sample['Freq of crime'],color="Red")
plt.xlabel("Day of Week")
plt.xticks(rotation=45)
plt.ylabel("Frequency of crime")
plt.title("The frequencies of crime each day of the week")
plt.show()
